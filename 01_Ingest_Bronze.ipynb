# %%
import requests

# 1. Fetch live data for the top 50 coins from CoinGecko
print("Calling CoinGecko API...")
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=50&page=1&sparkline=false"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(f"Successfully fetched {len(data)} coins.")
else:
    print(f"Error fetching data. Status code: {response.status_code}")
    data = []

# 2. Convert via pandas to handle mixed int/float types
import pandas as pd
df_pandas = pd.DataFrame(data)
df_raw = spark.createDataFrame(df_pandas)

# 3. Display the raw data
display(df_raw)
# Out:
# Calling CoinGecko API...
# Successfully fetched 50 coins.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Save the Spark DataFrame as a Delta table named "crypto_bronze"
# mode("overwrite") ensures we replace the old data with fresh data every time we run it
df_raw.write.format("delta").mode("overwrite").saveAsTable("crypto_bronze")

print("Successfully saved data to crypto_bronze table!")
# Out:
# Successfully saved data to crypto_bronze table!
